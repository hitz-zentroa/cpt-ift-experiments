# %%
import pandas as pd
import numpy as np

# %%
data = [
    {
        "model": "google/gemma-2-9b",
        "Base-en": np.mean([71.3, 48, 68.4,53.2]),
        "Base-eu": 46.61857143,
        "+CPT eu": 52.07142857,
        "+ IFT alpaca eu": 57.96285714
         
    }, {
        "model": "meta-llama/Llama-3.1-8B",
        "Base-en": np.mean([73, 48.3, 80.4, 83.4,68.9]),
        "Base-eu": 45.26871429,
        "+CPT eu": 59.86285714,
        "+ IFT alpaca eu": 59.09571429
    }
    
]

# %%
df = pd.DataFrame(data)
df
# Out:
#                      model  Base-en    Base-eu    +CPT eu  + IFT alpaca eu
# 0        google/gemma-2-9b   60.225  46.618571  52.071429        57.962857
# 1  meta-llama/Llama-3.1-8B   70.800  45.268714  59.862857        59.095714

# %%
import seaborn as sns
sns.set_theme()
# melt the dataframe to long format for seaborn
df_melted = df.melt(id_vars=["model"], var_name="Metric", value_name="Value")

# # create the bar plot
# plt.figure(figsize=(10, 6))
# sns.barplot(x="model", y="Value", hue="Metric", data=df_melted)

# show the legends
# show the bar value on top of the bar
ax = sns.barplot(x="model", y="Value", hue="Metric", data=df_melted)
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='gray', xytext=(0, 5),
                textcoords='offset points')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4)
plt.xticks(rotation=0)
plt.show()
