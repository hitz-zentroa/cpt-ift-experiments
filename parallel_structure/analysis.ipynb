# %%
import json
from matplotlib import pyplot as plt
import numpy as np

# %%
results_d12 = json.load(open("./perplexities.json", 'r'))
results_d21 = json.load(open("./perplexities_flipped.json", 'r'))

# %%
rpd = []
for r1, r2 in zip(results_d12, results_d21):
    
    rpd.append( abs(r1-r2)/(r1+r2) )

# %%
bins
# Out:
# array([0.        , 0.09999652, 0.19999303, 0.29998955, 0.39998606,
#        0.49998258, 0.5999791 , 0.69997561, 0.79997213, 0.89996864,
#        0.99996516])

# %%
5248/2
# Out:
# 2624.0

# %%
counts = [2852, 3303, 6672,  3973/2, 1973/2, 5034+ 2624+ 4734+3727, 2624+4874+ 6656+3728]

# %%
bins = [0.09999, 0.10998955, 0.321997561, 0.421997561, 0.79997213, 0.89996864, 0.99996516]

# %%
sum(counts)
# Out:
# 49801.0

# %%
len(bins),len(counts)
# Out:
# (7, 7)

# %%
plt.bar(bins, counts, width=0.01)
# plt.gca().set_xticks([i/10 for i in range(0,11,4)])
plt.xlabel('rpd of ppl')
plt.ylabel('freq')
plt.show()

# %%
# counts, bins = np.histogram(results_d21, bins=1000)
plt.hist(bins[:], bins, weights=counts, rwidth=0.5)
# Out:
# (array([ 2852. ,  3303. ,  6672. ,  1986.5,   986.5, 34001. ]),
#  array([0.09999   , 0.10998955, 0.32199756, 0.42199756, 0.79997213,
#         0.89996864, 0.99996516]),
#  <BarContainer object of 6 artists>)
